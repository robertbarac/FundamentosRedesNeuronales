# %% [markdown]
# # Data Augmentation

# %% [markdown]
# - Rotar hacia la izquierda o derecha
#
# - Hacer zoom
#
# - Reflect
#
# - Wrap
#
# - Desplazamiento diagonal
#
# - Más Brillo

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import matplotlib.pyplot as plt

# %%
datagen = ImageDataGenerator(
    rotation_range = 40, 
    width_shift_range=0.2, 
    height_shift_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True,
    fill_mode='nearest', 
    brightness_range=[0.4, 1.5]
)

# %%
img = load_img('../input/cnn-data-sources/Mara.jpeg')
plt.imshow(img)
x = img_to_array(img)
print(x.shape)
x = x.reshape((1,) + x.shape) # recibe 1 sola imagen de entrada, con la dimensión y la cantidad de canales
print(x.shape)
# Out:
# (800, 600, 3)
# (1, 800, 600, 3)

# %%
# Iterar sobre el generador de imágenes

i = 0
for batch in datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(array_to_img(batch[0]))
    i += 1
    if i % 10 == 0:
        break

plt.show()

# %%
train_generator = datagen.flow_from_directory(
    '../input/cnn-data-sources/cats_and_dogs/train', 
    target_size=(150,150), 
    batch_size=32, 
    class_mode='binary'
    )
# Out:
# Found 2000 images belonging to 2 classes.

# %%
train_generator[0][0].shape
# Out:
# (32, 150, 150, 3)

# %%
array_to_img(train_generator[0][0][1])
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
foto = load_img('../input/mis-fotos/35350391_1727167607375115_4709296859695284224_n.jpg')
x = img_to_array(foto)
x = x.reshape((1,) + x.shape)

# %%
i = 0
for batch in datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(array_to_img(batch[0]))
    i += 1
    if i % 10 == 0:
        break

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
im = io.imread('../input/cnn-data-sources/Mara.jpeg')

# %%
yo = io.imread('../input/cnn-data-sources/yo.png')
plt.imshow(yo)

# %%
plt.imshow(im)

# %%
#Vamos a separar la imagen por colores
r = im[:,:,0]
g = im[:,:,1]
b = im[:,:,2]

# %%
plt.imshow(r)

# %%
plt.imshow(g)

# %%
plt.imshow(b)

# %%
r.shape
# Out:
# (800, 600)

# %%
aux_dim = np.zeros([800,600])

# %%
red = np.dstack((r, aux_dim, aux_dim)).astype(np.uint8)
green = np.dstack((aux_dim, g, aux_dim)).astype(np.uint8)
blue = np.dstack((aux_dim, aux_dim, b)).astype(np.uint8)

# %%
plt.imshow(red)

# %%
plt.imshow(green)

# %%
plt.imshow(blue)

# %%
#imagen en negativo
im_neg_pos = 255 - im

# %%
plt.imshow(im_neg_pos)

# %%
#bajar resolución
im32 = (im//32) * 32
im128 = (im//128)*128

# %%
plt.imshow(im)

# %%
plt.imshow(im32)

# %%
plt.imshow(im128)

# %%
# Con esto hacemos zoom a la cara de la perra
# La primera pareja de números es para lo vertical, la segunda es para lo horizontal
plt.imshow(im[270:530, 150:400])
